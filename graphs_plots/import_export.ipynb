# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('import_export.csv')
data.set_index(data.columns[0], inplace=True)
display(data)
# Out:
#                          US   Peru    Trinidad & Tobago    Other Americas*  \
# Unnamed: 0
# North America           0.38  0.30                  0.46              0.14
# S. & Cent. America      7.48  0.18                  4.14              0.67
# Europe                 76.21  3.14                  4.21              0.33
# Middle East & Africa    1.03  0.00                  0.17              0.00
# Asia Pacific           29.28  1.70                  1.51              0.00
#
#                         Norway    Other Europe*   Russian Federation    Oman   \
# Unnamed: 0
# North America              0.00            0.00                  0.00    0.00
# S. & Cent. America         0.00            0.50                  0.08    0.00
# Europe                     5.45            2.26                 19.41    0.76
# Middle East & Africa       0.00            0.00                  0.10    0.59
# Asia Pacific               0.00            0.94                 23.08   13.96
#
#                         Qatar    United Arab Emirates   ...  Angola   Egypt   \
# Unnamed: 0                                              ...
# North America             0.00                    0.00  ...    0.00     0.00
# S. & Cent. America        0.19                    0.00  ...    0.00     0.14
# Europe                   20.83                    0.09  ...    3.69     3.16
# Middle East & Africa      6.21                    0.09  ...    0.00     0.00
# Asia Pacific             81.13                    7.52  ...    1.26     1.58
#
#                         Nigeria    Other Africa    Australia    Brunei   \
# Unnamed: 0
# North America               0.00            0.00         0.00      0.00
# S. & Cent. America          1.50            0.78         0.00      0.00
# Europe                      9.33            2.68         0.01      0.00
# Middle East & Africa        1.20            0.29         0.09      0.00
# Asia Pacific                5.52            5.46       107.30      6.17
#
#                         Indonesia    Malaysia    Papua New Guinea   \
# Unnamed: 0
# North America                 0.33        0.00                0.00
# S. & Cent. America            0.00        0.00                0.00
# Europe                        0.09        0.00                0.00
# Middle East & Africa          0.01        0.19                0.00
# Asia Pacific                 15.68       36.09               11.55
#
#                         Other Asia Pacific*
# Unnamed: 0
# North America                           0.00
# S. & Cent. America                      0.00
# Europe                                  0.19
# Middle East & Africa                    0.08
# Asia Pacific                            1.24
#
# [5 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('import_export.csv')
data.set_index(data.columns[0], inplace=True)
data = data.astype(float)
plt.figure(figsize=(18, 6))
sns.heatmap(data, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.title("LNG Import & Export (Billion Cubic Meter)")
plt.xlabel("Exporter")
plt.ylabel("Importer")
plt.show()
